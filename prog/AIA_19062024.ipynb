# %%
import glob
import csv
import pandas as pd

path_data = "../ANNOTATION_TRANSFORMED_AIA_ARCHI/DAUDET/*"
liste_annote=[]
for annotateur in glob.glob(path_data):
    for file in glob.glob("%s/*"%annotateur):
        annotation = pd.read_csv(file, on_bad_lines='skip')
        if "Kraken" in file:
            annotation.columns = ["Label"]
            liste_annote.append([annotation])
# Out:
# [[            Label
# 0             LA;
# 1       FABRIOUE;
# 2           \n\n;
# 3             EE;
# 4             \n;
# ...           ...
# 108278        \n;
# 108279         =;
# 108280         =;
# 108281         =;
# 108282        \n;
#
# [108283 rows x 1 columns]], [            Label
# 0             LA;
# 1       FABRIOUE;
# 2           \n\n;
# 3             EE;
# 4             \n;
# ...           ...
# 108278        \n;
# 108279         =;
# 108280         =;
# 108281         =;
# 108282        \n;
#
# [108283 rows x 1 columns]], [            Label
# 0             LA;
# 1       FABRIOUE;
# 2           \n\n;
# 3             EE;
# 4             \n;
# ...           ...
# 115971        \n;
# 115972         =;
# 115973         =;
# 115974         =;
# 115975        \n;
#
# [115976 rows x 1 columns]]]

# %%
# !pip install nltk
# Out:
# Collecting nltk
#   Downloading nltk-3.8.1-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: click in /home/caroline/environement_jup/jupyTR-env/lib64/python3.12/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /home/caroline/environement_jup/jupyTR-env/lib64/python3.12/site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /home/caroline/environement_jup/jupyTR-env/lib64/python3.12/site-packages (from nltk) (2024.5.15)
# Requirement already satisfied: tqdm in /home/caroline/environement_jup/jupyTR-env/lib64/python3.12/site-packages (from nltk) (4.66.2)
# Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 17.5 MB/s eta 0:00:00m eta 0:00:010:00:01
# Installing collected packages: nltk
# Successfully installed nltk-3.8.1

# %%
import pandas as pd
from  nltk.metrics import agreement

# Assume this CSV has the format <tweet_id>,<label>
# anno1_df = pd.read_csv("../ANNOTATION_TRANSFORMED_AIA_ARCHI/DAUDET/CF_DAUDET/CF_DAUDET_petit-chose_Kraken-base_spaCy3.7.2-lg.csv.aia.csv",sep=";", on_bad_lines='skip')
anno1_df = pd.read_csv("../ANNOTATION_TRANSFORMED_AIA_ARCHI/DAUDET/CF_DAUDET/CF_DAUDET_petit-chose_REF_spaCy3.7.2-lg.csv.aia.csv",sep=";", on_bad_lines='skip')
# anno1_df = pd.read_csv("../ANNOTATION_TRANSFORMED_AIA_ARCHI/DAUDET/CF_DAUDET/CF_DAUDET_petit-chose_TesseractFra-PNG_spaCy3.7.2-lg.csv.aia.csv",sep=";", on_bad_lines='skip')
anno1_df.columns = ["Token_1","Label_1"]
# print("pendant",anno1_df)
anno1_df=anno1_df.iloc[:6500]
print("pendant",anno1_df)


# Assume this CSV has the format <tweet_id>,<label>
# anno2_df = pd.read_csv("../ANNOTATION_TRANSFORMED_AIA_ARCHI/DAUDET/LM_DAUDET/LM_DAUDET_petit-chose_Kraken-base_spaCy3.7.2-lg.csv.aia.csv",sep=";",on_bad_lines='skip')
anno2_df = pd.read_csv("../ANNOTATION_TRANSFORMED_AIA_ARCHI/DAUDET/LM_DAUDET/LM_DAUDET_petit-chose_REF_spaCy3.7.2-lg.csv.aia.csv",sep=";",on_bad_lines='skip')
# anno2_df = pd.read_csv("../ANNOTATION_TRANSFORMED_AIA_ARCHI/DAUDET/LM_DAUDET/LM_DAUDET_petit-chose_TesseractFra-PNG_spaCy3.7.2-lg.csv.aia.csv",sep=";",on_bad_lines='skip')

anno2_df.columns = ["Token_2","Label_2"]
anno2_df=anno2_df.iloc[:6500]

# Assume this CSV has the format <tweet_id>,<label>
# anno3_df = pd.read_csv("../ANNOTATION_TRANSFORMED_AIA_ARCHI/DAUDET/MB_DAUDET/MB_DAUDET_petit-chose_Kraken-base_spaCy.3.7.3-lg.csv.aia.csv",sep=";",on_bad_lines='skip')
anno3_df = pd.read_csv("../ANNOTATION_TRANSFORMED_AIA_ARCHI/DAUDET/MB_DAUDET/MB_DAUDET_petit-chose_REF_spaCy3.7.2-lg.csv.aia.csv",sep=";",on_bad_lines='skip')
# anno3_df = pd.read_csv("../ANNOTATION_TRANSFORMED_AIA_ARCHI/DAUDET/MB_DAUDET/MB_DAUDET_petit-chose_TesseractFra-PNG_spaCy3.7.2-lg.csv.aia.csv",sep=";",on_bad_lines='skip')
anno3_df.columns = ["Token_3","Label_3"]
anno3_df=anno3_df.iloc[:6500]

# Join so we have a data frame of labels for each tweet ID
merged_df = anno1_df.join(anno2_df.join(anno3_df))

# We can drop rows where we don't have two labelers if we want
#. I think Krippendorf can account for missing data though, so this
#. step isn't strictly necessary if you only care about Krippendorf
labels_matched_df = merged_df.dropna()
print("labels_matched_df",labels_matched_df)
# Reformat the data into the form AnnotationTask
#  expects.
data = []
for idx, row in labels_matched_df.iterrows():
    data.append(("a1", idx, row["Label_1"]))
    data.append(("a2", idx, row["Label_2"]))
    data.append(("a3", idx, row["Label_3"]))
print("-----------------------------------------------------",data)
    
atask = agreement.AnnotationTask(data=data)

print("Cohen's Kappa:", atask.kappa())
print("Fleiss's Kappa:", atask.multi_kappa())

# This function maps labels into a numeric space,
#. so we can rely on the ordering of labels.
def priority_distance(left_label, right_label):
    mapped_labels = {
        "Critical": 4,
        "High": 3,
        "Medium": 2,
        "Low": 1,
    }
    left_i = mapped_labels[left_label]
    right_i = mapped_labels[right_label]
    
    return abs(left_i - right_i)

# Create a new annotation task with the distance function
# atask_2 = agreement.AnnotationTask(data=data, distance=priority_distance)
atask_2 = agreement.AnnotationTask(data=data)
print("Krippendorf's Alpha:", atask_2.alpha())
# Out:
# pendant        Token_1 Label_1
# 0     PREMIÈRE     NaN
# 1       PARTIE     NaN
# 2           \n     NaN
# 3            I     NaN
# 4           --     NaN
# ...        ...     ...
# 6495       les     NaN
# 6496    larmes     NaN
# 6497         ,     NaN
# 6498        et     NaN
# 6499        si     NaN
#
# [6500 rows x 2 columns]
# labels_matched_df         Token_1 Label_1    Token_2 Label_2    Token_3 Label_3
# 21    Languedoc     LOC  Languedoc     LOC  Languedoc     LOC
# 33         Midi     LOC       Midi     LOC       Midi     LOC
# 59           M.     PER         M.     PER         M.     PER
# 60     Eyssette     PER   Eyssette     PER   Eyssette     PER
# 202      maison     LOC     maison     LOC     maison     LOC
# ...         ...     ...        ...     ...        ...     ...
# 6419         Oh    MISC         Oh    MISC         Oh    MISC
# 6420          !    MISC          !    MISC          !    MISC
# 6466         M.     PER         M.     PER         M.     PER
# 6467   Eyssette     PER   Eyssette     PER   Eyssette     PER
# 6473    Jacques     PER    Jacques     PER    Jacques     PER
#
# [244 rows x 6 columns]
# ----------------------------------------------------- [('a1', 21, 'LOC'), ('a2', 21, 'LOC'), ('a3', 21, 'LOC'), ('a1', 33, 'LOC'), ('a2', 33, 'LOC'), ('a3', 33, 'LOC'), ('a1', 59, 'PER'), ('a2', 59, 'PER'), ('a3', 59, 'PER'), ('a1', 60, 'PER'), ('a2', 60, 'PER'), ('a3', 60, 'PER'), ('a1', 202, 'LOC'), ('a2', 202, 'LOC'), ('a3', 202, 'LOC'), ('a1', 203, 'LOC'), ('a2', 203, 'LOC'), ('a3', 203, 'LOC'), ('a1', 207, 'PER'), ('a2', 207, 'PER'), ('a3', 207, 'PER'), ('a1', 251, 'LOC'), ('a2', 251, 'LOC'), ('a3', 251, 'LOC'), ('a1', 265, 'PER'), ('a2', 265, 'PER'), ('a3', 265, 'PER'), ('a1', 266, 'PER'), ('a2', 266, 'PER'), ('a3', 266, 'PER'), ('a1', 292, 'LOC'), ('a2', 292, 'LOC'), ('a3', 292, 'LOC'), ('a1', 301, 'PER'), ('a2', 301, 'PER'), ('a3', 301, 'LOC'), ('a1', 302, 'PER'), ('a2', 302, 'PER'), ('a3', 302, 'LOC'), ('a1', 311, 'PER'), ('a2', 311, 'PER'), ('a3', 311, 'PER'), ('a1', 356, 'LOC'), ('a2', 356, 'LOC'), ('a3', 356, 'LOC'), ('a1', 380, 'PER'), ('a2', 380, 'PER'), ('a3', 380, 'PER'), ('a1', 576, 'PER'), ('a2', 576, 'PER'), ('a3', 576, 'PER'), ('a1', 578, 'PER'), ('a2', 578, 'PER'), ('a3', 578, 'PER'), ('a1', 579, 'PER'), ('a2', 579, 'PER'), ('a3', 579, 'PER'), ('a1', 581, 'PER'), ('a2', 581, 'PER'), ('a3', 581, 'PER'), ('a1', 582, 'PER'), ('a2', 582, 'PER'), ('a3', 582, 'PER'), ('a1', 583, 'PER'), ('a2', 583, 'PER'), ('a3', 583, 'PER'), ('a1', 587, 'PER'), ('a2', 587, 'PER'), ('a3', 587, 'PER'), ('a1', 606, 'PER'), ('a2', 606, 'PER'), ('a3', 606, 'PER'), ('a1', 607, 'PER'), ('a2', 607, 'PER'), ('a3', 607, 'PER'), ('a1', 608, 'PER'), ('a2', 608, 'PER'), ('a3', 608, 'PER'), ('a1', 612, 'PER'), ('a2', 612, 'PER'), ('a3', 612, 'PER'), ('a1', 613, 'PER'), ('a2', 613, 'PER'), ('a3', 613, 'PER'), ('a1', 614, 'PER'), ('a2', 614, 'PER'), ('a3', 614, 'PER'), ('a1', 725, 'LOC'), ('a2', 725, 'LOC'), ('a3', 725, 'LOC'), ('a1', 726, 'LOC'), ('a2', 726, 'LOC'), ('a3', 726, 'LOC'), ('a1', 727, 'LOC'), ('a2', 727, 'LOC'), ('a3', 727, 'LOC'), ('a1', 782, 'PER'), ('a2', 782, 'PER'), ('a3', 782, 'PER'), ('a1', 804, 'PER'), ('a2', 804, 'PER'), ('a3', 804, 'PER'), ('a1', 805, 'PER'), ('a2', 805, 'PER'), ('a3', 805, 'PER'), ('a1', 806, 'PER'), ('a2', 806, 'PER'), ('a3', 806, 'PER'), ('a1', 845, 'PER'), ('a2', 845, 'PER'), ('a3', 845, 'PER'), ('a1', 846, 'PER'), ('a2', 846, 'PER'), ('a3', 846, 'PER'), ('a1', 950, 'PER'), ('a2', 950, 'PER'), ('a3', 950, 'PER'), ('a1', 953, 'PER'), ('a2', 953, 'PER'), ('a3', 953, 'PER'), ('a1', 954, 'PER'), ('a2', 954, 'PER'), ('a3', 954, 'PER'), ('a1', 955, 'PER'), ('a2', 955, 'PER'), ('a3', 955, 'PER'), ('a1', 966, 'MISC'), ('a2', 966, 'MISC'), ('a3', 966, 'MISC'), ('a1', 1015, 'LOC'), ('a2', 1015, 'LOC'), ('a3', 1015, 'LOC'), ('a1', 1016, 'LOC'), ('a2', 1016, 'LOC'), ('a3', 1016, 'LOC'), ('a1', 1017, 'LOC'), ('a2', 1017, 'LOC'), ('a3', 1017, 'LOC'), ('a1', 1042, 'PER'), ('a2', 1042, 'PER'), ('a3', 1042, 'PER'), ('a1', 1089, 'PER'), ('a2', 1089, 'PER'), ('a3', 1089, 'PER'), ('a1', 1090, 'PER'), ('a2', 1090, 'PER'), ('a3', 1090, 'PER'), ('a1', 1189, 'PER'), ('a2', 1189, 'PER'), ('a3', 1189, 'PER'), ('a1', 1190, 'PER'), ('a2', 1190, 'PER'), ('a3', 1190, 'PER'), ('a1', 1191, 'PER'), ('a2', 1191, 'PER'), ('a3', 1191, 'PER'), ('a1', 1195, 'PER'), ('a2', 1195, 'PER'), ('a3', 1195, 'PER'), ('a1', 1227, 'PER'), ('a2', 1227, 'PER'), ('a3', 1227, 'PER'), ('a1', 1228, 'PER'), ('a2', 1228, 'PER'), ('a3', 1228, 'PER'), ('a1', 1234, 'PER'), ('a2', 1234, 'PER'), ('a3', 1234, 'PER'), ('a1', 1235, 'PER'), ('a2', 1235, 'PER'), ('a3', 1235, 'PER'), ('a1', 1236, 'PER'), ('a2', 1236, 'PER'), ('a3', 1236, 'PER'), ('a1', 1241, 'PER'), ('a2', 1241, 'PER'), ('a3', 1241, 'PER'), ('a1', 1242, 'PER'), ('a2', 1242, 'PER'), ('a3', 1242, 'PER'), ('a1', 1246, 'PER'), ('a2', 1246, 'PER'), ('a3', 1246, 'PER'), ('a1', 1283, 'PER'), ('a2', 1283, 'PER'), ('a3', 1283, 'PER'), ('a1', 1398, 'PER'), ('a2', 1398, 'PER'), ('a3', 1398, 'PER'), ('a1', 1399, 'PER'), ('a2', 1399, 'PER'), ('a3', 1399, 'PER'), ('a1', 1426, 'PER'), ('a2', 1426, 'PER'), ('a3', 14 ...
# Cohen's Kappa: 0.8602602810756811
# Fleiss's Kappa: 0.8568743250989855
# Krippendorf's Alpha: 0.856711364547601

# %%
import pandas as pd
from  nltk.metrics import agreement

# Assume this CSV has the format <tweet_id>,<label>
# anno1_df = pd.read_csv("../ANNOTATION_TRANSFORMED_AIA_ARCHI/CARRAUD/CF_CARRAUD/CF_CARRAUD_petite-Jeanne_Kraken-base_spaCy3.7.2-lg.csv.aia.csv",sep=";", on_bad_lines='skip')
# anno1_df = pd.read_csv("../ANNOTATION_TRANSFORMED_AIA_ARCHI/CARRAUD/CF_CARRAUD/CF_CARRAUD_petite-Jeanne_REF_spaCy3.7.2-lg.csv.aia.csv",sep=";", on_bad_lines='skip')
anno1_df = pd.read_csv("../ANNOTATION_TRANSFORMED_AIA_ARCHI/CARRAUD/CF_CARRAUD/CF_CARRAUD_petite-Jeanne_TesseractFra-PNG_spaCy3.7.2-lg.csv.aia.csv",sep=";", on_bad_lines='skip')
anno1_df.columns = ["Token_1","Label_1"]
# print("pendant",anno1_df)
anno1_df=anno1_df.iloc[:6500]
print("pendant",anno1_df)


# Assume this CSV has the format <tweet_id>,<label>
# anno2_df = pd.read_csv("../ANNOTATION_TRANSFORMED_AIA_ARCHI/CARRAUD/LM_CARRAUD/LM_CARRAUD_petite-Jeanne_Kraken-base_spaCy3.7.2-lg.csv.aia.csv",sep=";",on_bad_lines='skip')
# anno2_df = pd.read_csv("../ANNOTATION_TRANSFORMED_AIA_ARCHI/CARRAUD/LM_CARRAUD/LM_CARRAUD_petite-Jeanne_REF_spaCy3.7.2-lg.csv.aia.csv",sep=";",on_bad_lines='skip')
anno2_df = pd.read_csv("../ANNOTATION_TRANSFORMED_AIA_ARCHI/CARRAUD/LM_CARRAUD/LM_CARRAUD_petite-Jeanne_TesseractFra-PNG_spaCy3.7.2-lg.csv.aia.csv",sep=";",on_bad_lines='skip')

anno2_df.columns = ["Token_2","Label_2"]
anno2_df=anno2_df.iloc[:6500]

# Assume this CSV has the format <tweet_id>,<label>
# anno3_df = pd.read_csv("../ANNOTATION_TRANSFORMED_AIA_ARCHI/CARRAUD/MB_CARRAUD/MB_CARRAUD_petite-Jeanne_Kraken-base_spaCy3.7.2-lg.csv.aia.csv",sep=";",on_bad_lines='skip')
# anno3_df = pd.read_csv("../ANNOTATION_TRANSFORMED_AIA_ARCHI/CARRAUD/MB_CARRAUD/MB_CARRAUD_petite-Jeanne_REF_spaCy3.7.2-lg.csv.aia.csv",sep=";",on_bad_lines='skip')
anno3_df = pd.read_csv("../ANNOTATION_TRANSFORMED_AIA_ARCHI/CARRAUD/MB_CARRAUD/MB_CARRAUD_petite-Jeanne_TesseractFra-PNG_spaCy3.7.2-lg.csv.aia.csv",sep=";",on_bad_lines='skip')
anno3_df.columns = ["Token_3","Label_3"]
anno3_df=anno3_df.iloc[:6500]

# Join so we have a data frame of labels for each tweet ID
merged_df = anno1_df.join(anno2_df.join(anno3_df))

# We can drop rows where we don't have two labelers if we want
#. I think Krippendorf can account for missing data though, so this
#. step isn't strictly necessary if you only care about Krippendorf
labels_matched_df = merged_df.dropna()
print("labels_matched_df",labels_matched_df)
# Reformat the data into the form AnnotationTask
#  expects.
data = []
for idx, row in labels_matched_df.iterrows():
    data.append(("a1", idx, row["Label_1"]))
    data.append(("a2", idx, row["Label_2"]))
    data.append(("a3", idx, row["Label_3"]))
print("-----------------------------------------------------",data)
    
atask = agreement.AnnotationTask(data=data)

print("Cohen's Kappa:", atask.kappa())
print("Fleiss's Kappa:", atask.multi_kappa())

# This function maps labels into a numeric space,
#. so we can rely on the ordering of labels.
def priority_distance(left_label, right_label):
    mapped_labels = {
        "Critical": 4,
        "High": 3,
        "Medium": 2,
        "Low": 1,
    }
    left_i = mapped_labels[left_label]
    right_i = mapped_labels[right_label]
    
    return abs(left_i - right_i)

# Create a new annotation task with the distance function
# atask_2 = agreement.AnnotationTask(data=data, distance=priority_distance)
atask_2 = agreement.AnnotationTask(data=data)
print("Krippendorf's Alpha:", atask_2.alpha())
# Out:
# pendant       Token_1 Label_1
# 0      PETITE     PER
# 1      JEANNE     PER
# 2        \n\n     NaN
# 3          LE     NaN
# 4      DEVOIR     NaN
# ...       ...     ...
# 6495      pas     NaN
# 6496        à     NaN
# 6497       sa     NaN
# 6498  portion     NaN
# 6499       de     NaN
#
# [6500 rows x 2 columns]
# labels_matched_df        Token_1 Label_1   Token_2 Label_2   Token_3 Label_3
# 1       JEANNE     PER    JEANNE     PER    JEANNE     PER
# 16      JEANNE     PER    JEANNE     PER    JEANNE     PER
# 19          La     PER        La     PER        La     PER
# 20        mère     PER      mère     PER      mère     PER
# 21    Nannette     PER  Nannette     PER  Nannette     PER
# ...        ...     ...       ...     ...       ...     ...
# 6380    Jeanne     PER    Jeanne     PER    Jeanne     PER
# 6476    Jeanne     PER    Jeanne     PER    Jeanne     PER
# 6483       Mme     PER       Mme     PER       Mme     PER
# 6484    Dümont     PER    Dümont     PER    Dümont     PER
# 6488    Jeanne     PER    Jeanne     PER    Jeanne     PER
#
# [298 rows x 6 columns]
# ----------------------------------------------------- [('a1', 1, 'PER'), ('a2', 1, 'PER'), ('a3', 1, 'PER'), ('a1', 16, 'PER'), ('a2', 16, 'PER'), ('a3', 16, 'PER'), ('a1', 19, 'PER'), ('a2', 19, 'PER'), ('a3', 19, 'PER'), ('a1', 20, 'PER'), ('a2', 20, 'PER'), ('a3', 20, 'PER'), ('a1', 21, 'PER'), ('a2', 21, 'PER'), ('a3', 21, 'PER'), ('a1', 31, 'LOC'), ('a2', 31, 'LOC'), ('a3', 31, 'LOC'), ('a1', 32, 'LOC'), ('a2', 32, 'LOC'), ('a3', 32, 'LOC'), ('a1', 33, 'LOC'), ('a2', 33, 'LOC'), ('a3', 33, 'LOC'), ('a1', 34, 'LOC'), ('a2', 34, 'LOC'), ('a3', 34, 'LOC'), ('a1', 47, 'PER'), ('a2', 47, 'PER'), ('a3', 47, 'PER'), ('a1', 48, 'PER'), ('a2', 48, 'PER'), ('a3', 48, 'PER'), ('a1', 49, 'PER'), ('a2', 49, 'PER'), ('a3', 49, 'PER'), ('a1', 123, 'PER'), ('a2', 123, 'PER'), ('a3', 123, 'PER'), ('a1', 251, 'PER'), ('a2', 251, 'PER'), ('a3', 251, 'PER'), ('a1', 252, 'PER'), ('a2', 252, 'PER'), ('a3', 252, 'PER'), ('a1', 254, 'PER'), ('a2', 254, 'PER'), ('a3', 254, 'PER'), ('a1', 328, 'PER'), ('a2', 328, 'PER'), ('a3', 328, 'PER'), ('a1', 329, 'PER'), ('a2', 329, 'PER'), ('a3', 329, 'PER'), ('a1', 331, 'PER'), ('a2', 331, 'PER'), ('a3', 331, 'PER'), ('a1', 453, 'PER'), ('a2', 453, 'PER'), ('a3', 453, 'PER'), ('a1', 454, 'PER'), ('a2', 454, 'PER'), ('a3', 454, 'PER'), ('a1', 455, 'PER'), ('a2', 455, 'PER'), ('a3', 455, 'PER'), ('a1', 554, 'PER'), ('a2', 554, 'PER'), ('a3', 554, 'PER'), ('a1', 602, 'PER'), ('a2', 602, 'PER'), ('a3', 602, 'PER'), ('a1', 603, 'PER'), ('a2', 603, 'PER'), ('a3', 603, 'PER'), ('a1', 605, 'PER'), ('a2', 605, 'PER'), ('a3', 605, 'PER'), ('a1', 610, 'PER'), ('a2', 610, 'PER'), ('a3', 610, 'PER'), ('a1', 611, 'PER'), ('a2', 611, 'PER'), ('a3', 611, 'PER'), ('a1', 612, 'PER'), ('a2', 612, 'PER'), ('a3', 612, 'PER'), ('a1', 658, 'MISC'), ('a2', 658, 'MISC'), ('a3', 658, 'MISC'), ('a1', 664, 'MISC'), ('a2', 664, 'MISC'), ('a3', 664, 'MISC'), ('a1', 748, 'PER'), ('a2', 748, 'PER'), ('a3', 748, 'PER'), ('a1', 750, 'PER'), ('a2', 750, 'PER'), ('a3', 750, 'PER'), ('a1', 757, 'PER'), ('a2', 757, 'PER'), ('a3', 757, 'PER'), ('a1', 758, 'PER'), ('a2', 758, 'PER'), ('a3', 758, 'PER'), ('a1', 759, 'PER'), ('a2', 759, 'PER'), ('a3', 759, 'PER'), ('a1', 812, 'PER'), ('a2', 812, 'PER'), ('a3', 812, 'PER'), ('a1', 813, 'PER'), ('a2', 813, 'PER'), ('a3', 813, 'PER'), ('a1', 815, 'PER'), ('a2', 815, 'PER'), ('a3', 815, 'PER'), ('a1', 869, 'PER'), ('a2', 869, 'PER'), ('a3', 869, 'PER'), ('a1', 870, 'PER'), ('a2', 870, 'PER'), ('a3', 870, 'PER'), ('a1', 871, 'PER'), ('a2', 871, 'PER'), ('a3', 871, 'PER'), ('a1', 1016, 'MISC'), ('a2', 1016, 'MISC'), ('a3', 1016, 'MISC'), ('a1', 1021, 'PER'), ('a2', 1021, 'PER'), ('a3', 1021, 'PER'), ('a1', 1118, 'PER'), ('a2', 1118, 'PER'), ('a3', 1118, 'PER'), ('a1', 1119, 'PER'), ('a2', 1119, 'PER'), ('a3', 1119, 'PER'), ('a1', 1120, 'PER'), ('a2', 1120, 'PER'), ('a3', 1120, 'PER'), ('a1', 1135, 'PER'), ('a2', 1135, 'PER'), ('a3', 1135, 'PER'), ('a1', 1136, 'PER'), ('a2', 1136, 'PER'), ('a3', 1136, 'PER'), ('a1', 1137, 'PER'), ('a2', 1137, 'PER'), ('a3', 1137, 'PER'), ('a1', 1305, 'PER'), ('a2', 1305, 'PER'), ('a3', 1305, 'PER'), ('a1', 1401, 'PER'), ('a2', 1401, 'PER'), ('a3', 1401, 'PER'), ('a1', 1403, 'PER'), ('a2', 1403, 'PER'), ('a3', 1403, 'PER'), ('a1', 1404, 'PER'), ('a2', 1404, 'PER'), ('a3', 1404, 'PER'), ('a1', 1442, 'PER'), ('a2', 1442, 'PER'), ('a3', 1442, 'PER'), ('a1', 1446, 'PER'), ('a2', 1446, 'PER'), ('a3', 1446, 'PER'), ('a1', 1447, 'PER'), ('a2', 1447, 'PER'), ('a3', 1447, 'PER'), ('a1', 1448, 'PER'), ('a2', 1448, 'PER'), ('a3', 1448, 'PER'), ('a1', 1452, 'PER'), ('a2', 1452, 'LOC'), ('a3', 1452, 'PER'), ('a1', 1465, 'PER'), ('a2', 1465, 'PER'), ('a3', 1465, 'MISC'), ('a1', 1466, 'PER'), ('a2', 1466, 'PER'), ('a3', 1466, 'MISC'), ('a1', 1473, 'PER'), ('a2', 1473, 'PER'), ('a3', 1473, 'PER'), ('a1', 1474, 'PER'), ('a2', 1474, 'PER'), ('a3', 1474, 'PER'), ('a1', 1481, 'PER'), ('a2', 1481, 'PER'), ('a3', 1481, 'PER'), ('a1', 1601, 'PER'), ('a2', 1601, 'PER'), ('a3', 1601, 'PER'), ('a1 ...
# Cohen's Kappa: 0.6286793442166316
# Fleiss's Kappa: 0.6024739267523654
# Krippendorf's Alpha: 0.6017352875590423

# %%
from sklearn.metrics import cohen_kappa_score

import pandas as pd


# Assume this CSV has the format <tweet_id>,<label>
anno1_df = pd.read_csv("../ANNOTATION_TRANSFORMED_AIA_ARCHI/DAUDET/CF_DAUDET/CF_DAUDET_petit-chose_Kraken-base_spaCy3.7.2-lg.csv.aia.csv",sep=";", on_bad_lines='skip')
anno1_df.columns = ["Token_1","Label_1"]
# print("pendant",anno1_df)
anno1_df=anno1_df.iloc[:6500]
print("pendant",anno1_df)


# Assume this CSV has the format <tweet_id>,<label>
anno2_df = pd.read_csv("../ANNOTATION_TRANSFORMED_AIA_ARCHI/DAUDET/LM_DAUDET/LM_DAUDET_petit-chose_Kraken-base_spaCy3.7.2-lg.csv.aia.csv",sep=";",on_bad_lines='skip')
anno2_df.columns = ["Token_2","Label_2"]
anno2_df=anno2_df.iloc[:6500]

print(cohen_kappa_score(anno1_df, anno2_df, labels=None))
# Out:
# pendant          Token_1 Label_1
# 0             LA     NaN
# 1       FABRIOUE     NaN
# 2           \n\n     NaN
# 3             EE     NaN
# 4             \n     NaN
# ...          ...     ...
# 6495          la     NaN
# 6496  sentinelle     NaN
# 6497      criait     NaN
# 6498           :     NaN
# 6499                 NaN
#
# [6500 rows x 2 columns]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[61], line 19
#      16 anno2_df.columns = ["Token_2","Label_2"]
#      17 anno2_df=anno2_df.iloc[:6500]
# ---> 19 print(cohen_kappa_score(anno1_df, anno2_df, labels=None))
#
# File ~/environement_jup/jupyTR-env/lib64/python3.12/site-packages/sklearn/utils/_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File ~/environement_jup/jupyTR-env/lib64/python3.12/site-packages/sklearn/metrics/_classification.py:691, in cohen_kappa_score(y1, y2, labels, weights, sample_weight)
#     617 @validate_params(
#     618     {
#     619         "y1": ["array-like"],
#    (...)
#     626 )
#     627 def cohen_kappa_score(y1, y2, *, labels=None, weights=None, sample_weight=None):
#     628     r"""Compute Cohen's kappa: a statistic that measures inter-annotator agreement.
#     629
#     630     This function computes Cohen's kappa [1]_, a score that expresses the level
#    (...)
#     689     0.6875
#     690     """
# --> 691     confusion = confusion_matrix(y1, y2, labels=labels, sample_weight=sample_weight)
#     692     n_classes = confusion.shape[0]
#     693     sum0 = np.sum(confusion, axis=0)
#
# File ~/environement_jup/jupyTR-env/lib64/python3.12/site-packages/sklearn/utils/_param_validation.py:186, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     184 global_skip_validation = get_config()["skip_parameter_validation"]
#     185 if global_skip_validation:
# --> 186     return func(*args, **kwargs)
#     188 func_sig = signature(func)
#     190 # Map *args/**kwargs to the function signature
#
# File ~/environement_jup/jupyTR-env/lib64/python3.12/site-packages/sklearn/metrics/_classification.py:319, in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     224 @validate_params(
#     225     {
#     226         "y_true": ["array-like"],
#    (...)
#     235     y_true, y_pred, *, labels=None, sample_weight=None, normalize=None
#     236 ):
#     237     """Compute confusion matrix to evaluate the accuracy of a classification.
#     238
#     239     By definition a confusion matrix :math:`C` is such that :math:`C_{i, j}`
#    (...)
#     317     (0, 2, 1, 1)
#     318     """
# --> 319     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     320     if y_type not in ("binary", "multiclass"):
#     321         raise ValueError("%s is not supported" % y_type)
#
# File ~/environement_jup/jupyTR-env/lib64/python3.12/site-packages/sklearn/metrics/_classification.py:86, in _check_targets(y_true, y_pred)
#      59 """Check that y_true and y_pred belong to the same classification task.
#      60
#      61 This converts multiclass or binary types to a common shape, and raises a
#    (...)
#      83 y_pred : array or indicator matrix
#      84 """
#      85 check_consistent_length(y_true, y_pred)
# ---> 86 type_true = type_of_target(y_true, input_name="y_true")
#      87 type_pred = type_of_target(y_pred, input_name="y_pred")
#      89 y_type = {type_true, type_pred}
#
# File ~/environement_jup/jupyTR-env/lib64/python3.12/site-packages/sklearn/utils/multiclass.py:316, in type_of_target(y, input_name)
#     313 if sparse_pandas:
#     314     raise ValueError("y cannot be class 'SparseSeries' or 'SparseArray'")
# --> 316 if is_multilabel(y):
#     317     return "multilabel-indicator"
#     319 # DeprecationWarning will be replaced by ValueError, see NEP 34
#     320 # https://numpy.org/neps/nep-0034-infer-dtype-is-object.html
#     321 # We therefore catch both deprecation (NumPy < 1.24) warning and
#     322 # value error (NumPy >= 1.24).
#
# File ~/environement_jup/jupyTR-env/lib64/python3.12/site-packages/sklearn/utils/multiclass.py:193, in is_multilabel(y)
#     187     return (
#     188         len(y.data) == 0
#     189         or (labels.size == 1 or (labels.size == 2) and (0 in labels))
#     190         and (y.dtype.kind in "biu" or _is_integral_float(labels))  # bool, int, uint
#     191     )
#     192 else:
# --> 193     labels = xp.unique_values(y)
#     195     return labels.shape[0] < 3 and (
#     196         xp.isdtype(y.dtype, ("bool", "signed integer", "unsigned integer"))
#     197         or _is_integral_float(labels)
#     198     )
#
# File ~/environement_jup/jupyTR-env/lib64/python3.12/site-packages/sklearn/utils/_array_api.py:307, in _NumPyAPIWrapper.unique_values(self, x)
#     306 def unique_values(self, x):
# --> 307     return numpy.unique(x)
#
# File ~/environement_jup/jupyTR-env/lib64/python3.12/site-packages/numpy/lib/arraysetops.py:274, in unique(ar, return_index, return_inverse, return_counts, axis, equal_nan)
#     272 ar = np.asanyarray(ar)
#     273 if axis is None:
# --> 274     ret = _unique1d(ar, return_index, return_inverse, return_counts,
#     275                     equal_nan=equal_nan)
#     276     return _unpack_tuple(ret)
#     278 # axis was specified and not None
#
# File ~/environement_jup/jupyTR-env/lib64/python3.12/site-packages/numpy/lib/arraysetops.py:336, in _unique1d(ar, return_index, return_inverse, return_counts, equal_nan)
#     334     aux = ar[perm]
#     335 else:
# --> 336     ar.sort()
#     337     aux = ar
#     338 mask = np.empty(aux.shape, dtype=np.bool_)
#
# TypeError: '<' not supported between instances of 'float' and 'str'
